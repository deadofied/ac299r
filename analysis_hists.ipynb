# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

from fnmatch import fnmatch

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from pattern import web
import math


# set some nicer defaults for matplotlib
from matplotlib import rcParams

dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843),
                (0.4, 0.4, 0.4)]

rcParams['figure.figsize'] = (20, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.grid'] = False
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'none'

def histogram_style():
    remove_border(left=False)
    plt.grid(False)
    plt.grid(axis='y', color='w', linestyle='-', lw=1)
    
def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesary plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()

# %%
profiles = pd.read_csv('data/brides18full.csv')
profiles['gender'] = 0

for i in range(19, 52):
    profiles2 = pd.read_csv('data/brides'+str(i)+'full.csv')
    profiles2['gender'] = 0
    profiles = profiles.append(profiles2)
for i in range(18, 52):
    profiles2 = pd.read_csv('data/grooms'+str(i)+'full.csv')
    profiles2['gender'] = 1
    profiles = profiles.append(profiles2)
    
print profiles
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325688 entries, 0 to 4525
# Data columns (total 67 columns):
# about1             144133  non-null values
# about2             46030  non-null values
# about_family       30026  non-null values
# age2               226644  non-null values
# birth1             324598  non-null values
# birth2             121566  non-null values
# birth3             226238  non-null values
# birth4             139883  non-null values
# body1              222435  non-null values
# body2              63175  non-null values
# brothers           105802  non-null values
# caste1             305231  non-null values
# caste2             153690  non-null values
# city2              68051  non-null values
# college            109448  non-null values
# complexion1        229865  non-null values
# complexion2        63524  non-null values
# created_for        320097  non-null values
# degree             321616  non-null values
# ...

# %%
total = len(profiles)
males = len(profiles[profiles.gender==1])
females = len(profiles[profiles.gender==0])

print 'Total profiles: ', total
print 'Number of males: ', males
print 'Number of females: ', females
print 'Percent of males: ', float(males) / float(total) * 100
print 'Percent of females: ', float(females) / float(total) * 100
# Out:
# Total profiles:  325688
# Number of males:  248893
# Number of females:  76795
# Percent of males:  76.4206848272
# Percent of females:  23.5793151728

# %%
profiles.religion1 = profiles.religion1.replace({'Hindu': 0, 'Muslim': 1, 'Christian': 2, 'Sikh': 3, 'Buddhist': 4, 'Jain': 5, 'Parsi':6, 'Spiritual': 7, 'Jewish': 8, 'Others': 9})
profiles['religion1']=profiles['religion1'].map(lambda x: int(x) if not math.isnan(x) else None)

# %%
profiles.eating1 = profiles.eating1.replace({'Doesn\'t Matter':0, 'Jain': 1, 'Vegetarian': 2, 'Vegetarian With Eggs': 3, 'Non Vegetarian':4})
profiles['eating1']=profiles['eating1'].map(lambda x: int(x) if not math.isnan(x) else None)

# %%
profiles.status1 = profiles.status1.replace({'Doesn\'t Matter': 0, 'Middle Class': 1, 'Upper Middle Class': 2, 'High Class': 3, 'Rich / Affluent':4})
profiles['status1']=profiles['status1'].map(lambda x: int(x) if not math.isnan(x) else None)

# %%
profiles.marital_status1 = profiles.marital_status1.replace({'Doesn\'t Matter': 0, 'Never Married': 1, 'Divorced': 2, 'Annulled': 3, 'Widowed': 4, 'Married': 5})
profiles['marital_status1']=profiles['marital_status1'].map(lambda x: int(x) if not math.isnan(x) else None)

# %%
profiles.family_type1 = profiles.family_type1.replace({'Doesn\'t Matter': 0, 'Others':3, 'Nuclear': 1, 'Joint family both parents': 2, 'Joint family only mother':2, 'Joint family father mother and brothers sisters':2, 'Joint family single parent brothers and or sisters':2, 'Joint family only father': 2})
profiles['family_type1']=profiles['family_type1'].map(lambda x: int(x) if not math.isnan(x) else None)

# %%
profiles.manglik1 = profiles.manglik1.replace({'No': 0, 'Yes': 1, 'Do Not Know': 2, 'Doesn\'t Matter': 3, 'Anshik': 4})
profiles['manglik1']=profiles['manglik1'].map(lambda x: int(x) if not math.isnan(x) else None)

# %%
profiles.horoscope = profiles.horoscope.replace({'No': 0, 'Yes': 1})
profiles['horoscope']=profiles['horoscope'].map(lambda x: int(x) if not math.isnan(x) else None)

# %%
profiles.drinking1 = profiles.drinking1.replace({'Doesn\'t Matter':0, 'No': 1, 'Occasionally': 2, 'Yes': 3})
profiles['drinking1']=profiles['drinking1'].map(lambda x: int(x) if not math.isnan(x) else None)

# %%
profiles.smoking1 = profiles.smoking1.replace({'Doesn\'t Matter': 0, 'No': 1, 'Moderate': 2, 'Yes': 3})
profiles['smoking1']=profiles['smoking1'].map(lambda x: int(x) if not math.isnan(x) else None)

# %%
profiles.values1 = profiles.values1.replace({'Orthodox': 1, 'Orthrodox': 1, 'Traditional': 2, 'Moderate': 3, 'Liberal': 4, 'Modern': 5, 'International':6, 'Others': 7})
profiles['values1']=profiles['values1'].map(lambda x: int(x) if not math.isnan(x) else None)

# %%
profiles['age1'] = profiles['details'].map(lambda x: str(x)[0:2] if str(x) != '' else '')
profiles['age1']=profiles['age1'].map(lambda x: int(x) if x != 'na' else None)

# %%
profiles.body1 = profiles.body1.replace({'Slim': 1, 'Average': 2, 'Heavy': 3, 'Athletic': 4, 'Doesn\'t Matter':0})
profiles['body1']=profiles['body1'].map(lambda x: int(x) if not math.isnan(x) else None)

# %%
hist1, bins1 = np.histogram(profiles[profiles.gender==1].age1, bins=np.linspace(18, 75, 58))
hist1 = [(float(i)/float(sum(hist1)))*100.0 for i in hist1]
hist0, bins0 = np.histogram(profiles[profiles.gender==0].age1, bins=np.linspace(18, 75, 58))
hist0 = [(float(i)/float(sum(hist0)))*100.0 for i in hist0]
plt.title("Distribution of Age")
plt.bar([i for i in range(18, 75)], height=hist1, align='center', color='#30A7FC', alpha=0.5, label='Men')
plt.bar([i for i in range(18, 75)], height=hist0, align='center', color='#FC9DEB', alpha=0.5, label='Women')
plt.xlabel('Age (Years)')
plt.ylabel('Percentage of Profiles')
plt.axvline(x=28, ymin=0, ymax=11, c='black', label='Median=28 yrs')
plt.legend(frameon=False, loc='upper right')
ax = plt.gca()
ax.set_xlim([18,75])
remove_border()
#xticks_locs, xticks_labels = plt.xticks([i for i in range(18, 76)], [i for i in range(17, 75)])

# %%
import string

def getweight(wt): 
    weight = str(wt)
    
    s = [int(s) for s in weight.split() if s.isdigit()]
    
    if len(s) == 2:
        if 'Pound' not in weight:
            toReturn = int((s[0] + s[1]) / 2)
        else:
            toReturn = int((0.5 * (s[0] + s[1]))/2.2)
    elif len(s) == 1:
        if len(s) == 1 and 'Pound' not in weight:
            toReturn = int(s[0])
        elif len(s) == 1 and 'Pound' in weight:
            toReturn = int(s[0] / 2.2)
    else:
        return np.nan
            
    if toReturn != 0 and toReturn >= 40 and toReturn <= 140:
        return toReturn
    else:
        return np.nan

# %%
profiles['kgs'] = profiles['weight1'].map(lambda x: getweight(x))

# %%
hist1, bins1 = np.histogram(profiles[profiles.gender==1].kgs, bins=np.linspace(40, 120, 81))
hist1 = [(float(i)/float(sum(hist1)))*100.0 for i in hist1]
hist0, bins0 = np.histogram(profiles[profiles.gender==0].kgs, bins=np.linspace(40, 120, 81))
hist0 = [(float(i)/float(sum(hist0)))*100.0 for i in hist0]
plt.title("Distribution of Weight")
plt.bar([i for i in range(40, 120)], height=hist1, align='center', color='#30A7FC', alpha=0.5, label='Men')
plt.bar([i for i in range(40, 120)], height=hist0, align='center', color='#FC9DEB', alpha=0.5, label='Women')
plt.xlabel('Weight (kg)')
plt.ylabel('Percentage of Profiles')
plt.axvline(x=50, ymin=0, ymax=11, c='red', label='Women Median=50 kg')
plt.axvline(x=65, ymin=0, ymax=11, c='blue', label='Men Median=65 kg')
plt.legend(frameon=False, loc='upper right')
ax = plt.gca()
ax.set_xlim([40,100])
remove_border()
#xticks_locs, xticks_labels = plt.xticks([i for i in range(18, 76)], [i for i in range(17, 75)])

# %%
def from_one(height):
    feet, inches = 0, 0
    if "to" not in height:
        if 'ft' in height:
            feet = int(height[0])
        
        if 'in' in height:
            inches = int(height[4:-2])
            
        return feet * 12 + inches



def convert(height):
    height = str(height)
    num = 0
    
    if height == "Doesn't Matter" or height == "Doesn't Matter to ":
        num = 0
    elif height == "5ft to Doesn't Matter":
        num = 60
    elif "to Doesn't Matter" in height:
        num = from_one(height[:-18])
    elif "Doesn't Matter to " in height:
        num = from_one(height[18:])
    
    if "to" not in height:
        num = from_one(height)
        
    if "to" in height:
        heights = height.split(" to ")
        num = int(from_one(heights[0]) + from_one(heights[1]) / 2)
        
    if (num >= 48 and num <= 84):
        return num
    else:
        return np.nan

# %%
profiles['height']=profiles['height1'].map(lambda x: convert(x))

# %%
hist1, bins1 = np.histogram(profiles[profiles.gender==1].height, bins=np.linspace(53, 83, 31))
hist1 = [(float(i)/float(sum(hist1)))*100.0 for i in hist1]
hist0, bins0 = np.histogram(profiles[profiles.gender==0].height, bins=np.linspace(53, 83, 31))
hist0 = [(float(i)/float(sum(hist0)))*100.0 for i in hist0]
plt.title("Distribution of Height")
plt.bar([i for i in range(53, 83)], height=hist1, align='center', color='#30A7FC', alpha=0.5, label='Men')
plt.bar([i for i in range(53, 83)], height=hist0, align='center', color='#FC9DEB', alpha=0.5, label='Women')
plt.xlabel('Height (inches)')
plt.ylabel('Percentage of Profiles')
plt.axvline(x=63, ymin=0, ymax=11, c='red', label='Women Median=63 inches')
plt.axvline(x=68, ymin=0, ymax=11, c='blue', label='Men Median=68 inches')
plt.legend(frameon=False, loc='upper right')
ax = plt.gca()
ax.set_xlim([53,83])
remove_border()
#xticks_locs, xticks_labels = plt.xticks([i for i in range(18, 76)], [i for i in range(17, 75)])

# %%
profiles['bmi'] = profiles['kgs'] / ((profiles['height']*0.0254)**2)

# %%
hist1, bins1 = np.histogram(profiles[profiles.gender==1].bmi, bins=np.linspace(10, 40, 31))
hist1 = [(float(i)/float(sum(hist1)))*100.0 for i in hist1]
hist0, bins0 = np.histogram(profiles[profiles.gender==0].bmi, bins=np.linspace(10, 40, 31))
hist0 = [(float(i)/float(sum(hist0)))*100.0 for i in hist0]
plt.title("Distribution of BMI")
plt.bar([i for i in range(10, 40)], height=hist1, align='center', color='#30A7FC', alpha=0.5, label='Men')
plt.bar([i for i in range(10, 40)], height=hist0, align='center', color='#FC9DEB', alpha=0.5, label='Women')
plt.xlabel('Body Mass Index')
plt.ylabel('Percentage of Profiles')
plt.axvline(x=20, ymin=0, ymax=11, c='red', label='Women Median=20')
plt.axvline(x=22, ymin=0, ymax=11, c='blue', label='Men Median=22')
plt.legend(frameon=False, loc='upper right')
ax = plt.gca()
remove_border()
ax.set_xlim([10,40])
# Out:
# (10, 40)

# %%
profiles['kgs2'] = profiles['weight2'].map(lambda x: getweight(x))

# %%
plt.plot(profiles[profiles.gender==0].kgs, profiles[profiles.gender==0].kgs2, 'o', mec='w', color='#FC9DEB', alpha=0.5, label='Women')
plt.title("Desired Partner Weight vs Own Weight")
plt.xlabel("Own weight (kg)")
plt.ylabel("Desired partner weight = (min + max) / 2")
plt.plot(profiles[profiles.gender==1].kgs, profiles[profiles.gender==1].kgs2, 'o', mec='w', color='#30A7FC', alpha=0.5, label='Men')
plt.plot([40, 100], [45, 105], c='gray', alpha=0.5)
plt.legend(frameon=True, loc='upper right')
plt.ylim([40,100])
plt.xlim([40,120])
remove_border()
plt.show()

# %%
plt.plot(profiles['kgs'][(profiles.gender==0) & (profiles["body1"] == 2)], ((profiles['height'][(profiles.gender==0) & (profiles["body1"] == 2)])*0.0254)**2, 'o', mec='b', color='w', alpha=0.5, label='Average')
plt.plot(profiles['kgs'][(profiles.gender==0) & (profiles["body1"] == 4)], ((profiles['height'][(profiles.gender==0) & (profiles["body1"] == 4)])*0.0254)**2, 'o', mec='w', color='g', alpha=0.5, label='Athletic')
plt.plot(profiles['kgs'][(profiles.gender==0) & (profiles["body1"] == 1)], ((profiles['height'][(profiles.gender==0) & (profiles["body1"] == 1)])*0.0254)**2, 'o', mec='w', color='r', alpha=0.5, label='Slim')
plt.plot(profiles['kgs'][(profiles.gender==0) & (profiles["body1"] == 0)], ((profiles['height'][(profiles.gender==0) & (profiles["body1"] == 0)])*0.0254)**2, 'o', mec='w', color='#000000', alpha=0.5, label='Doesn\'t Matter')
plt.plot(profiles['kgs'][(profiles.gender==0) & (profiles["body1"] == 3)], ((profiles['height'][(profiles.gender==0) & (profiles["body1"] == 3)])*0.0254)**2, 'o', mec='w', color='b', alpha=0.5, label='Heavy')
plt.title("Women: BMI (Height^2 vs Weight) & Self-Selection of Body Type")
plt.ylabel("Height^2 (m^2)")
plt.xlabel("Weight (kg)")
plt.plot([45, 80], [2, 3.4], c='gray', alpha=0.5)
plt.xlim([37.5,100])
plt.ylim([2,3.5])
plt.legend(frameon=True, loc='upper right')
remove_border()

# %%
plt.plot(profiles['kgs'][(profiles.gender==1) & (profiles["body1"] == 2)], ((profiles['height'][(profiles.gender==1) & (profiles["body1"] == 2)])*0.0254)**2, 'o', color='w',  mec='b',alpha=0.5, label='Average')
plt.plot(profiles['kgs'][(profiles.gender==1) & (profiles["body1"] == 4)], ((profiles['height'][(profiles.gender==1) & (profiles["body1"] == 4)])*0.0254)**2, 'o', color='g', mec='w', alpha=0.5, label='Athletic')
plt.plot(profiles['kgs'][(profiles.gender==1) & (profiles["body1"] == 1)], ((profiles['height'][(profiles.gender==1) & (profiles["body1"] == 1)])*0.0254)**2, 'o', color='r', mec='w', alpha=0.5, label='Slim')
plt.plot(profiles['kgs'][(profiles.gender==1) & (profiles["body1"] == 0)], ((profiles['height'][(profiles.gender==1) & (profiles["body1"] == 0)])*0.0254)**2, 'o', color='#000000',  mec='w',alpha=0.5, label='Doesn\'t Matter')
plt.plot(profiles['kgs'][(profiles.gender==1) & (profiles["body1"] == 3)], ((profiles['height'][(profiles.gender==1) & (profiles["body1"] == 3)])*0.0254)**2, 'o', color='b',  mec='w',alpha=0.5, label='Heavy')
plt.title("Men: BMI (Height^2 vs Weight) & Self-Selection of Body Type")
plt.ylabel("Height^2 (m^2)")
plt.xlabel("Weight (kg)")
plt.plot([60, 90], [2.25, 3.7], c='gray', alpha=0.5)
plt.xlim([40,120])
plt.ylim([2.25,3.75])
plt.legend(frameon=True, loc='lower right')
remove_border()

# %%
def get_income(income):
    income = str(income)
    
    if income =='nan':
        ret = np.nan
    elif income == 'INR Under 50 thousand':
        ret = 0
    elif income == 'INR 50 thousand to 1 lakh':
        ret = 1
    elif income == 'INR 1 lakh to 2 lakhs':
        ret = 2
    elif income == 'INR 2 lakhs to 3 lakhs':
        ret = 3
    elif income == 'INR 3 lakhs to 4 lakhs':
        ret = 4
    elif income == 'INR 4 lakhs to 5 lakhs':
        ret = 5
    elif income == 'INR 5 lakhs to 7 lakhs':
        ret = 6
    elif income == 'INR 7 lakhs to 10 lakhs':
        ret = 7
    elif income == 'INR 10 lakhs to 15 lakhs':
        ret = 8
    elif income == 'INR 15 lakhs to 20 lakhs':
        ret = 9
    elif income == 'INR 20 lakhs to 25 lakhs' or income == 'INR 25 lakhs to 30 lakhs' or income == 'INR 30 lakhs to 35 lakhs' or income == 'INR 35 lakhs to 40 lakhs' or income == 'INR 40 lakhs to 50 lakhs' or income == '50 lakhs and above.':
        ret = 10
    else:
        ret = np.nan
        
    return ret

#profiles['income1']=profiles['income1'].map(lambda x: get_income(x))
sorted(profiles.income1.unique())
# Out:
# [nan,
#  ' 3 lakhs to 4 lakhs',
#  ' 7 lakhs to 10 lakhs',
#  " Don't wish to specify",
#  '$100k to 125k,$125k to 150k,$150k to 200k,$200k and above',
#  '$200k and above',
#  '$25k to 40k',
#  '$25k to 40k,$40k to 60k,$60k to 80k,$80k to 100k,$100k to 125k,$125k to 150k,$150k to 200k,$200k and above',
#  '$60k to 80k',
#  '$80k to 100k',
#  '$80k to 100k,$100k to 125k',
#  '&euro;150k to 200k,&euro;200k and above',
#  '&pound;40k to 50k,&pound;50k to 75k,&pound;75k to 100k,&pound;100k and above',
#  '1 lakh to 2 lakhs',
#  '1 lakh to 2 lakhs,2 lakhs to 3 lakhs',
#  '1 lakh to 2 lakhs,2 lakhs to 3 lakhs,3 lakhs to 4 lakhs,4 lakhs to 5 lakhs,7 lakhs to 10 lakhs',
#  '1 lakh to 2 lakhs,2 lakhs to 3 lakhs,3 lakhs to 4 lakhs,4 lakhs to 5 lakhs,7 lakhs to 10 lakhs,10 lakhs to 15 lakhs,15 lakhs to 20 lakhs,20 lakhs to 25 lakhs,25 lakhs to 30 lakhs,30 lakhs to 35 lakhs,35 lakhs to 40 lakhs,40 lakhs to 50 lakhs,50 lakhs and above.',
#  '1 lakh to 2 lakhs,3 lakhs to 4 lakhs',
# ...

# %%
def get_education(degree):
    degree = str(degree)
    
    if degree =='nan' or degree == 'Others':
        ret = np.nan
    elif degree == '10th' or degree =='12th' or degree == 'Other School/ Graduation' or degree == 'Intermediate':
        ret = 0 #High school
    elif degree == 'Other Diploma' or degree =='Pilot Licenses' or degree=='Languages' or degree=='CS (Company Secretary)':
        ret = 1 #Some college
    elif degree[0] == 'B' or degree =='Undergraduate' or degree == 'PG Diploma' or degree == 'LLB' or degree == 'ICWA' or degree == 'Fashion/ Design' or degree == 'Engineering':
        ret = 2 #Undergrad
    elif degree[0] == 'M' or degree =='Other Post Graduation' or degree == 'Integrated PG' or degree == 'PGDBM' or degree == 'CA (Chartered Accountant)' or degree == 'CFA (Chartered Financial Analyst)':
        ret = 3 #Grad
    elif degree == 'Ph.D. (Doctorate)' or degree=='Other Doctorate':
        ret = 4 #Doctorate
    else:
        ret = np.nan
        
    return ret

profiles['education1']=profiles['degree'].map(lambda x: get_education(x))
profiles.education1.unique()
# Out:
# array([  2.,   0.,   3.,   1.,  nan,   4.])

# %%
def getloc(details):
    details = str(details)
    detailslen = len(details.split('<br />'))
    details2 = details.split('<br />')[detailslen-1]
    
    if details2.count(",") == 2:
        wholestring = details2.split(',', 1)[1].strip()
    else:
        wholestring = details2.strip()
        
    finalsize = len(wholestring.split(',', 1))

    if finalsize == 2:
        return wholestring.split(',', 1)[0].strip(), wholestring.split(',', 1)[1].strip()
    elif finalsize == 1:
        return "", wholestring.split(',', 1)[0].strip()
    else:
        return "", ""

# %%
print getloc("18 yrs, 5ft 3in,<br /> Catholic, Christian, Malayalam ,<br /> Integrated PG, Admin/Secretarial, <br /> Albertville, United States of America")
print getloc("18 yrs, 5ft 6in,<br /> Sunni, Muslim, Urdu ,<br /> 12th, Bangalore, India")
print getloc("18 yrs, 5ft 2in,<br /> Mudaliyar, Hindu, Tamil ,<br /> 12th, Chennai, India")


temp = """18 yrs, 5ft 5in,<br />
					
					
					
					
													
						Buddhist, 
						
					
						
						Marathi ,<br />
																							
					
					
					
				
					
							B.A. (Arts), 				
					
						  	
					 
					
					Chandrapur,
					 India"""

print getloc(temp)

temp2 = """18 yrs, 6ft 3in,<br />
					
					
													
						Catholic,
					
					
													
						Christian, 
						
					
						
						Koshali ,<br />
																							
					
					
					
				
					
							10th, 				
					
						  	
					
					Business Owner / Entrepreneur, <br />
					 
					
					Mumbai,
					 India"""

print getloc(temp2)

print getloc("18 yrs, 5ft 7in,<br /> Catholic, Christian, German ,<br /> BHM (Hotel Management), Cote D Ivoire")

print getloc("20 yrs, 5ft 3in,<br /> Baishya, Hindu, Bengali ,<br /> B.Com (Commerce), Kolkata, India")
# Out:
# ('Albertville', 'United States of America')
# ('Bangalore', 'India')
# ('Chennai', 'India')
# ('Chandrapur', 'India')
# ('Mumbai', 'India')
# ('BHM (Hotel Management)', 'Cote D Ivoire')
# ('Kolkata', 'India')

# %%
smallprofiles = pd.read_csv('links/brides18.csv')

for i in range(19, 52):
    smallprofiles2 = pd.read_csv('links/brides'+str(i)+'.csv')
    smallprofiles = smallprofiles.append(smallprofiles2)
for i in range(18, 52):
    smallprofiles2 = pd.read_csv('links/grooms'+str(i)+'.csv')
    smallprofiles = smallprofiles.append(smallprofiles2)
    
cityprofiles = smallprofiles[['city', 'profileID']]

# %%
profiles = profiles.drop_duplicates(cols="profileID")

# %%
profiles = profiles.reset_index(drop=True)

# %%
cityprofiles = cityprofiles.drop_duplicates(cols="profileID")
cityprofiles = cityprofiles.reset_index(drop=True)

# %%
profiles = profiles.set_index(['profileID'])

# %%
cityprofiles = cityprofiles.set_index(['profileID'])

# %%
profiles = profiles.join(cityprofiles)

# %%
sorted(profiles.city.unique())
# Out:
# [nan,
#  'Abbottabad, North-West Frontier',
#  'Aberaeron, Ceredigion',
#  'Abertillery, Blaenau Gwent',
#  'Abha, Asir',
#  'Abqaiq, Eastern Province',
#  'Abu Dhabi, Abu Dhabi',
#  'Accokeek, Maryland',
#  'Acworth, Georgia',
#  'Adamsville, Alabama',
#  'Addison, Texas',
#  'Adelaide , South Australia',
#  'Adelaide Hills, South Australia',
#  'Adelanto, California',
#  'Adilabad, Andhra Pradesh, India',
#  'Afif, Ar-Riyad',
#  'Agartala, Tripura, India',
#  'Agra, Uttar Pradesh, India',
#  'Ahmedabad, Gujarat, India',
#  'Ahmednagar, Maharashtra, India',
#  'Ahwa, Gujarat, India',
#  'Aiken, South Carolina',
#  'Airdrie, Alberta',
#  'Aizwal, Mizoram, India',
#  'Ajman, Ajman',
#  'Ajmer, Rajasthan, India',
#  'Akbarpur, Uttar Pradesh, India',
#  'Akola, Maharashtra, India',
#  'Al Ain, Abu Dhabi',
#  'Al Bahah, Al Bahah',
#  'Al Jawf, Al Jawf',
#  'Al Kharj, Ar-Riyad',
#  'Al Wajh, Tabuk',
#  'Al-An, Abu Dhabi',
#  'Al-Khobar, Eastern Province',
#  'Alabama',
# ...

# %%
temp = profiles.groupby('city').count().city
# Out:
# city
# Abbottabad, North-West Frontier      1
# Aberaeron, Ceredigion                1
# Abertillery, Blaenau Gwent           2
# Abha, Asir                           4
# Abqaiq, Eastern Province             4
# Abu Dhabi, Abu Dhabi               322
# Accokeek, Maryland                   1
# Acworth, Georgia                     1
# Adamsville, Alabama                 18
# Addison, Texas                       3
# Adelaide , South Australia          57
# Adelaide Hills, South Australia      6
# Adelanto, California                 4
# Adilabad, Andhra Pradesh, India    236
# Afif, Ar-Riyad                       3
# ...
# Worksop, Nottinghamshire                 1
# Worthing, Sussex                         1
# Yakima, Washington                       1
# Yamuna Nagar, Haryana, India           334
# Yanam, Pondicherry, India                4
# Yavatmal, Maharashtra, India           126
# Yingkiong, Arunachal Pradesh, India      3
# Yonkers, New York                        3
# ...

# %%
temp2 = temp.copy()
temp2.sort(ascending=False)

# %%
temp2.head(50)
# Out:
# city
# Delhi, Delhi, India                              36766
# Mumbai, Maharashtra, India                       24482
# Bangalore, Karnataka, India                      21097
# Pune, Maharashtra, India                         11102
# Hyderabad, Andhra Pradesh, India                 10708
# Chennai, Tamil Nadu, India                       10060
# Kolkata, West Bengal, India                       7788
# Others                                            6916
# Ahmedabad, Gujarat, India                         5153
# Lucknow, Uttar Pradesh, India                     5078
# Gurgaon, Haryana, India                           3231
# Chandigarh, Chandigarh, India                     3117
# Jaipur, Rajasthan, India                          2976
# Nagpur, Maharashtra, India                        2780
# Ghaziabad, Uttar Pradesh, India                   2744
# Ludhiana, Punjab, India                           2560
# Noida, Uttar Pradesh, India                       2544
# ...

# %%
def loc_type(location):
    location = str(location)
        
    metros = ["Delhi, Delhi, India", "Mumbai, Maharashtra, India", "Bangalore, Karnataka, India", "Pune, Maharashtra, India", "Hyderabad, Andhra Pradesh, India", "Chennai, Tamil Nadu, India", "Kolkata, West Bengal, India", "Gurgaon, Haryana, India", "Rest of Delhi, Delhi, India"] 
    US_states = ["Alabama", "Alaska", "American Samoa", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "District of Columbia", "Florida", "Georgia", "Guam", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Northern Marianas Islands", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Virgin Islands", "Washington", "West Virginia", "Wisconsin", "Wyoming"]
    
    if location in US_states:
        return 1
    elif location in metros:
        return 2
    elif "India" in location:
        return 3
    else:
        return 4

# %%
profiles['location']=profiles['city'].map(lambda x: loc_type(x))
profiles.location.unique()
# Out:
# array([3, 2, 4, 1])
