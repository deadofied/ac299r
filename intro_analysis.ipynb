# %% [markdown]
# # Introductory Data Analysis

# %%
# %matplotlib inline

import json

import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 30)

# set some nicer defaults for matplotlib
from matplotlib import rcParams

#these colors come from colorbrewer2.org. Each is an RGB triplet
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843),
                (0.4, 0.4, 0.4)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.grid'] = False
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'none'


def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesary plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()

# %%
profiles = pd.read_csv('data_cleaned/marathi_cleaned.csv')

# %%
#Your code here
def histogram_style():
    remove_border(left=False)
    plt.grid(False)
    plt.grid(axis='y', color='w', linestyle='-', lw=1)

profiles[profiles.gender==0].height1.hist(bins = np.linspace(55, 75, 20), edgecolor='white')
plt.xlabel("Height in inches")
plt.ylabel("N")
plt.title("Distribution of Women's Height")
histogram_style()
plt.show()
plt.clf()

profiles[profiles.gender==1].height1.hist(bins = np.linspace(55, 75, 20), edgecolor='white')
plt.xlabel("Height in inches")
plt.ylabel("N")
plt.title("Distribution of Men's Height")
histogram_style()

# %%
profiles[profiles.gender==0].weight1.hist(bins = np.linspace(30, 100, 70), edgecolor='white')
plt.xlabel("Weight in kg")
plt.ylabel("N")
plt.title("Distribution of Women's Weight")
histogram_style()
plt.show()
plt.clf()

profiles[profiles.gender==1].weight1.hist(bins = np.linspace(30, 100, 70), edgecolor='white')
plt.xlabel("Weight in kg")
plt.ylabel("N")
plt.title("Distribution of Men's Weight")
histogram_style()

# %%
plt.plot(profiles[profiles.gender==0].weight2, profiles[profiles.gender==0].weight1, 'o', label='Weight in Kg')
plt.title("Women: Desired Partner Weight vs Own Weight")
plt.xlabel("Weight in kg")
plt.ylabel("Desired partner weight = (min + max) / 2")
plt.show()
plt.clf()
plt.plot(profiles[profiles.gender==1].weight2, profiles[profiles.gender==1].weight1, 'o', label='Weight in Kg')
plt.title("Men: Desired Partner Weight vs Own Weight")
plt.xlabel("Weight in kg")
plt.ylabel("Desired partner weight = (min + max) / 2")
plt.ylim([40,100])
plt.show()

# %%
plt.plot(profiles[profiles.gender==1].height1, profiles[profiles.gender==1].weight1, 'o', label=' ')
plt.title("Men: Height vs Weight")
plt.xlabel("Weight in kg")
plt.ylabel("Height in Inches")
plt.ylim([40,100])
plt.xlim([55,80])
plt.show()
plt.clf()
plt.plot(profiles[profiles.gender==0].height1, profiles[profiles.gender==0].weight1, 'o', label=' ')
plt.title("Women: Height vs Weight")
plt.xlabel("Weight in kg")
plt.ylabel("Height in Inches")
plt.xlim([55,75])
plt.show()

# %%
plt.plot(profiles['weight1'][(profiles["gender"] == 0) & (profiles["body1"] == 4)], profiles['body1'][(profiles["gender"] == 0) & (profiles["body1"] == 4)], 'o', color='r', label="Athletic")
plt.plot(profiles['weight1'][(profiles["gender"] == 0) & (profiles["body1"] == 3)], profiles['body1'][(profiles["gender"] == 0) & (profiles["body1"] == 3)], 'o', color='#FFA500', label="Heavy")
plt.plot(profiles['weight1'][(profiles["gender"] == 0) & (profiles["body1"] == 2)], profiles['body1'][(profiles["gender"] == 0) & (profiles["body1"] == 2)], 'o', color='g', label="Average")
plt.plot(profiles['weight1'][(profiles["gender"] == 0) & (profiles["body1"] == 1)], profiles['body1'][(profiles["gender"] == 0) & (profiles["body1"] == 1)], 'o', color='b', label="Slim")
plt.plot(profiles['weight1'][(profiles["gender"] == 0) & (profiles["body1"] == 0)], profiles['body1'][(profiles["gender"] == 0) & (profiles["body1"] == 0)], 'o', color='#000000', label="Doesn't Matter")
plt.title("Women: Reported Body Type vs Reported Weight")
plt.xlabel("Weight in kg")
plt.ylim([-0.5,4.5])
plt.xlim([35,115])
plt.legend(loc='lower right')
plt.show()
plt.clf()
plt.plot(profiles['weight1'][(profiles["gender"] == 1) & (profiles["body1"] == 4)], profiles['body1'][(profiles["gender"] == 1) & (profiles["body1"] == 4)], 'o', color='r', label="Athletic")
plt.plot(profiles['weight1'][(profiles["gender"] == 1) & (profiles["body1"] == 3)], profiles['body1'][(profiles["gender"] == 1) & (profiles["body1"] == 3)], 'o', color='#FFA500', label="Heavy")
plt.plot(profiles['weight1'][(profiles["gender"] == 1) & (profiles["body1"] == 2)], profiles['body1'][(profiles["gender"] == 1) & (profiles["body1"] == 2)], 'o', color='g', label="Average")
plt.plot(profiles['weight1'][(profiles["gender"] == 1) & (profiles["body1"] == 1)], profiles['body1'][(profiles["gender"] == 1) & (profiles["body1"] == 1)], 'o', color='b', label="Slim")
plt.plot(profiles['weight1'][(profiles["gender"] == 1) & (profiles["body1"] == 0)], profiles['body1'][(profiles["gender"] == 1) & (profiles["body1"] == 0)], 'o', color='#000000', label="Doesn't Matter")
plt.title("Men: Reported Body Type vs Reported Weight")
plt.xlabel("Weight in kg")
plt.ylim([-0.5,4.5])
plt.xlim([35,115])
plt.legend(loc='lower right')
plt.show()

# %%
def count_unique(keys):
    uniq_keys = np.unique(keys)
    bins = uniq_keys.searchsorted(keys)
    return uniq_keys, np.bincount(bins)

x = profiles['body1'][(profiles["gender"] == 0)].dropna().astype(int)
y = np.bincount(profiles['body1'][(profiles["gender"] == 0)].dropna().astype(int))
ii = np.nonzero(y)[0]

x2 = profiles['body1'][(profiles["gender"] == 1)].dropna().astype(int)
y2 = np.bincount(profiles['body1'][(profiles["gender"] == 1)].dropna().astype(int))
ii2 = np.nonzero(y)[0]

zip(ii,y[ii])
# Out:
# [(0, 98), (1, 1328), (2, 2632), (3, 98), (4, 286)]

# %%
ind = np.arange(5)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, y2[ii2], width, color='r')
rects2 = ax.bar(ind+width, y[ii], width, color='y')

# add some
ax.set_ylabel('Number of profiles')
ax.set_title('Self-selection of body type')
ax.set_xticks(np.arange(5)+width)
ax.set_xticklabels( ("Doesn't \nMatter", "Slim", 'Average', 'Heavy', 'Athletic') )

ax.legend( (rects1[0], rects2[0]), ('Men', 'Women') )

plt.show()

# %%
x = profiles['complexion1'][(profiles["gender"] == 0)].dropna().astype(int)
y = np.bincount(profiles['complexion1'][(profiles["gender"] == 0)].dropna().astype(int))
ii = np.nonzero(y)[0]

x2 = profiles['complexion1'][(profiles["gender"] == 1)].dropna().astype(int)
y2 = np.bincount(profiles['complexion1'][(profiles["gender"] == 1)].dropna().astype(int))
ii2 = np.nonzero(y)[0]

zip(ii,y[ii])
# Out:
# [(0, 107), (1, 293), (2, 2169), (3, 1542), (4, 462), (5, 27)]

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(np.arange(6), y2[ii2], width, color='r')
rects2 = ax.bar(np.arange(6)+width, y[ii], width, color='y')

# add some
ax.set_ylabel('Number of profiles')
ax.set_title('Self-selection of body complexion')
ax.set_xticks(np.arange(6)+width)
ax.set_xticklabels( ("Doesn't \nMatter", "Very Fair", 'Fair', 'Wheatish', 'Wheatish \nMedium', 'Dark') )

ax.legend( (rects1[0], rects2[0]), ('Men', 'Women') )
plt.show()

# %%
x = profiles['eating1'].dropna().astype(int)
y = np.bincount(profiles['eating1'].dropna().astype(int))
ii = np.nonzero(y)[0]

zip(ii,y[ii])
# Out:
# [(0, 166), (1, 29), (2, 2761), (3, 1314), (4, 5072)]

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(np.arange(5)+width, y[ii], width, color='r')

# add some
ax.set_ylabel('Number of profiles')
ax.set_title('Personal diet preferences')
ax.set_xticks(np.arange(5)+(1.5*width))
ax.set_xticklabels( ("Doesn't \nMatter", "Jain", 'Vegetarian', 'Vegetarian \nwith Eggs', 'Non Vegetarian') )

plt.show()

# %%
x = profiles['drinking1'][(profiles["gender"] == 0)].dropna().astype(int)
y = np.bincount(profiles['drinking1'][(profiles["gender"] == 0)].dropna().astype(int))
ii = np.nonzero(y)[0]

x2 = profiles['drinking1'][(profiles["gender"] == 1)].dropna().astype(int)
y2 = np.bincount(profiles['drinking1'][(profiles["gender"] == 1)].dropna().astype(int))
ii2 = np.nonzero(y)[0]

zip(ii,y[ii])

fig, ax = plt.subplots()
rects1 = ax.bar(np.arange(4), y2[ii2], width, color='r')
rects2 = ax.bar(np.arange(4)+width, y[ii], width, color='y')

# add some
ax.set_ylabel('Number of profiles')
ax.set_title('Personal drinking preferences')
ax.set_xticks(np.arange(4)+width)
ax.set_xticklabels( ("Doesn't \nMatter", "No", 'Occassionally', 'Yes') )

ax.legend( (rects1[0], rects2[0]), ('Men', 'Women') )

plt.show()
plt.clf()

x = profiles['smoking1'][(profiles["gender"] == 0)].dropna().astype(int)
y = np.bincount(profiles['smoking1'][(profiles["gender"] == 0)].dropna().astype(int))
ii = np.nonzero(y)[0]

x2 = profiles['smoking1'][(profiles["gender"] == 1)].dropna().astype(int)
y2 = np.bincount(profiles['smoking1'][(profiles["gender"] == 1)].dropna().astype(int))
ii2 = np.nonzero(y)[0]

zip(ii,y[ii])

fig, ax = plt.subplots()
rects1 = ax.bar(np.arange(4), y2[ii2], width, color='r')
rects2 = ax.bar(np.arange(4)+width, y[ii], width, color='y')

# add some
ax.set_ylabel('Number of profiles')
ax.set_title('Personal smoking preferences')
ax.set_xticks(np.arange(4)+width)
ax.set_xticklabels( ("Doesn't \nMatter", "No", 'Moderate', 'Yes') )

ax.legend( (rects1[0], rects2[0]), ('Men', 'Women') )
        
plt.show()

# %%
x = profiles['status1'].dropna().astype(int)
y = np.bincount(profiles['status1'].dropna().astype(int))
ii = np.nonzero(y)[0]

zip(ii,y[ii])
# Out:
# [(0, 187), (1, 3592), (2, 2099), (3, 65), (4, 51)]

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(np.arange(5)+width, y[ii], width, color='r')

# add some
ax.set_ylabel('Number of profiles')
ax.set_title('Economic Status')
ax.set_xticks(np.arange(5)+(1.5*width))
ax.set_xticklabels( ("Doesn't \nMatter", "Middle \nClass", 'Upper\n Middle\n Class', 'High\nClass', 'Rich') )
        
plt.show()

# %%
x = profiles['marital_status1'].dropna().astype(int)
y = np.bincount(profiles['marital_status1'].dropna().astype(int))
ii = np.nonzero(y)[0]

zip(ii,y[ii])
# Out:
# [(1, 9695), (2, 849), (3, 71), (4, 154), (5, 1)]

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(np.arange(5)+width, y[ii], width, color='r')

# add some
ax.set_ylabel('Number of profiles')
ax.set_title('Marital status')
ax.set_xticks(np.arange(4)+(1.5*width))
ax.set_xticklabels( ("Never married", 'Divorced', 'Annulled', 'Widowed') )
        
plt.show()

# %%
x = profiles['religion1'].dropna().astype(int)
y = np.bincount(profiles['religion1'].dropna().astype(int))
ii = np.nonzero(y)[0]

zip(ii,y[ii])
# Out:
# [(0, 9161),
#  (1, 30),
#  (2, 202),
#  (3, 5),
#  (4, 1214),
#  (5, 133),
#  (6, 3),
#  (7, 4),
#  (8, 18)]

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(np.arange(9)+width, y[ii], width, color='r')
# add some
ax.set_ylabel('Number of profiles')
ax.set_title('Religion')
ax.set_xticks(np.arange(9)+(1.5*width))
ax.set_xticklabels( ("Hindu", 'Muslim', 'Christian', 'Sikh', 'Buddhist', 'Jain', 'Spiritual', 'Jewish', 'Others') )
        
plt.show()

# %%
x = profiles['values1'].dropna().astype(int)
y = np.bincount(profiles['values1'].dropna().astype(int))
ii = np.nonzero(y)[0]

zip(ii,y[ii])
# Out:
# [(1, 46), (2, 1541), (3, 2838), (4, 916), (5, 381), (6, 7), (7, 46)]

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(np.arange(7)+width, y[ii], width, color='r')

# add some
ax.set_ylabel('Number of profiles')
ax.set_title('Values')
ax.set_xticks(np.arange(7)+(1.5*width))
ax.set_xticklabels( ("Orthodox", 'Traditional', 'Moderate', 'Liberal', 'Modern', 'International', 'Others') )

#ax.legend( (rects1[0], rects2[0]), ('Men', 'Women') )
        
plt.show()
